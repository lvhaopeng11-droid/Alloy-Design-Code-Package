# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.legend_handler import HandlerPatch
gradient = np.linspace(0, 1, 256).reshape(1, -1)
gradient = np.vstack((gradient, gradient))
# 铺满整个图片，将extent参数设为(0, 1, 0, 1)
ax.imshow(gradient, aspect='auto', cmap='Blues', extent=(0, 1, 0, 1))
# Create a custom color map for the gradient effect
colors = ['#b4e7a0', '#f3cc7a']
cmap = LinearSegmentedColormap.from_list('Gradient', colors, N=len(colors))

fig, ax = plt.subplots(figsize=(8, 4), dpi=600)
plt.grid(axis="y", c='#d2c9eb', linestyle='--', zorder=0)

f1_1 = [0.70, 0.92, 0.88, 0.93, 0.64]  # R2
f1_2 = [18.24, 5.00, 8.75, 4.45, 20.81]  # MAPE
x = ['SVR', 'RF', 'GUSS', 'XGB', 'BPNN']
x_ticks = np.arange(len(x))
total_width, n = 0.4, 3
width = 0.2
xticks = x_ticks - (total_width - width) / 2

# Bar plots for f1_1 with gradient color
f1_1_bar = plt.bar(xticks, f1_1, width=0.87 * width, label='$R^2$', edgecolor='black',
                   linewidth=1, zorder=10, color=cmap(0.0), alpha=0.5)  # Use the first color in the colormap
for bar in f1_1_bar:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}',
             ha='center', va='bottom', fontproperties='Times New Roman', fontsize=8)
for bar in f1_1_bar:
    bar.set_hatch('//////')

# Secondary y-axis for f1_2
ax2 = ax.twinx()
# Bar plots for f1_2 with gradient color
f1_2_bar = plt.bar(xticks + width, f1_2, width=0.87 * width, label='MAPE', edgecolor='black',
                   linewidth=1, zorder=10, color=cmap(1.0), alpha=0.7)  # Use the second color in the colormap
for bar in f1_2_bar:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}',
             ha='center', va='bottom', fontproperties='Times New Roman', fontsize=8)
for bar in f1_2_bar:
    bar.set_hatch('//////')

class HandlerBarLabel(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize):
        x = width / 2
        y = height / 2
        label = plt.Text(x, y, orig_handle,
                         fontsize=fontsize,
                         ha="center", va="center", fontweight='bold')
        return [label]

# Legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, handler_map={plt.Rectangle: HandlerBarLabel()}, fancybox=True,
          framealpha=0.5, prop={'family': 'Times New Roman', 'size': 8}, ncol=2,
          bbox_to_anchor=(0.75, 1), loc='upper left')
ax2.legend(prop={'family': 'Times New Roman', 'size': 8}, ncol=2)

plt.xticks(x_ticks, x, fontproperties='Times New Roman', fontsize=8)
plt.yticks(fontproperties='Times New Roman', fontsize=10)
plt.ylim(0, 30)
ax.set_ylim(0, 1)
ax.set_ylabel('$R^2$', fontproperties='Times New Roman', fontsize=10)
plt.ylabel("MAPE (%)", fontproperties='Times New Roman', fontsize=8)
plt.text(0.15, 0.83, 'UTS', fontsize=12, fontweight='bold', transform=fig.transFigure,
         color='white')  # Set text color to white

# Customize spines
ax.spines['bottom'].set_linewidth('1.0')
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_linewidth('1.0')
ax.spines['top'].set_color('black')
ax.spines['right'].set_linewidth('1.0')
ax.spines['right'].set_color('black')
ax.spines['left'].set_linewidth('1.0')
ax.spines['left'].set_color('black')

# Set all tick lines inward
ax.tick_params(axis='both', direction='in')
ax2.tick_params(axis='both', direction='in')

plt.show()

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerPatch

f1_1 = [0.70, 0.92, 0.88, 0.93, 0.64]  # R2
f1_2 = [18.24, 5.00, 8.75, 4.45, 20.81]  # MAPE
x = ['SVR', 'RFR', 'GUSS', 'XGB', 'BPNN']
# 设置背景图片
img = plt.imread('2.png')
ax.imshow(img, extent=[0, len(x), 0, 30], aspect='auto', zorder=0)
x_ticks = np.arange(len(x))
total_width, n = 0.6, 3
width = 0.4
xticks = x_ticks - (total_width - width) / 2
plt.figure(figsize=(6, 4), dpi=600)
ax = plt.axes()
plt.grid(axis="y", c='#d2c9eb', linestyle='--', zorder=0)

# 第一个柱状图的绘制
f1_1_bar = plt.bar(xticks, f1_1, width=0.77 * width, label='$R^2$', color='#cfcfe5', edgecolor='#66CCCC',
                   linewidth=1, zorder=15)
for bar in f1_1_bar:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}',
             ha='center', va='bottom', fontproperties='Times New Roman', fontsize=10, fontweight='bold')

# 第二个柱状图的绘制
ax2 = ax.twinx()
f1_2_bar = plt.bar(xticks + width, f1_2, width=0.77 * width, label='MAPE', color='#7262ac', edgecolor='#66CCCC',
                   linewidth=1, zorder=15)
for bar in f1_2_bar:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}',
             ha='center', va='bottom', fontproperties='Times New Roman', fontsize=10, fontweight='bold')

class HandlerBarLabel(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize):
        x = width / 5
        y = height / 5
        label = plt.Text(x, y, orig_handle,
                         fontsize=fontsize,
                         ha="center", va="center")
        return [label]

handles, labels = ax.get_legend_handles_labels()  # 添加图例
ax.legend(handles, labels, handler_map={plt.Rectangle: HandlerBarLabel()}, fancybox=True,
          framealpha=0.5, prop={'family': 'Times New Roman', 'weight': 'bold','size': 8}, ncol=2,
          bbox_to_anchor=(0.65, 1), loc='upper left')
ax2.legend(prop={'family': 'Times New Roman', 'weight': 'bold','size': 8}, ncol=2)

plt.xticks(x_ticks, x, fontproperties='Times New Roman', fontsize=8)
plt.yticks(fontproperties='Times New Roman', fontsize=10)
plt.yticks(fontproperties='Times New Roman', fontsize=8, fontweight='bold')  # 加粗显示纵坐标标签
plt.ylim(0, 30)
ax.set_ylim(0, 1.2)

for label in ax.yaxis.get_ticklabels():
    label.set_fontname('Times New Roman')
    label.set_fontsize(10)
    label.set_fontweight('bold')

ax.set_ylabel('$R^2$', fontproperties='Times New Roman', fontsize=10, fontweight='bold',labelpad=10)
plt.ylabel("MAPE(%)", fontproperties='Times New Roman', fontsize=8, fontweight='bold',labelpad=10)
ax.set_xticklabels(x, fontstyle='italic', fontweight='bold', fontsize=10, fontname='Times New Roman')

for spine in ax.spines.values():
    spine.set_linewidth(1.5)
    spine.set_color('black')

ax.tick_params(axis='both', direction='in')
ax2.tick_params(axis='both', direction='in')

plt.show()
